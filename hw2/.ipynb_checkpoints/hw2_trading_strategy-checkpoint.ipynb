# %% [markdown]
# # FINM 35910 - Homework 2
# 1. Forumlate Investment Hypothesis and Goals
#
# 2. Portfolio Construction and Rebalancing
#
# 3. Evaluate Backtesting Results

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import time
from datetime import datetime
import pandas_ta as ta
import ccxt
import seaborn as sn
import statsmodels.tsa.stattools as ts
from statsmodels.tsa.stattools import adfuller
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

sys.path.insert(0, parent_dir)

from algo_tools import algo_tools as ats

import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Historical data

# %%
coinbase = ccxt.coinbase()
reloadedMarkets = coinbase.load_markets(reload=True)

def load_crypto_data(exchange, since, symbol, timeframe):
    data = []
    print(symbol)
    while since < exchange.milliseconds():
        try:
            ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, params={})
            data += ohlcv
            since = max(ohlcv)[0] + 1
            print(pd.to_datetime(since, unit='ms'))
            # time.sleep(1)
        except Exception as e:
            print('Error:', e)
            break
    print('Done')
    
    data = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

    data['date'] = pd.to_datetime(data['timestamp'],unit='ms').dt.tz_localize('UTC').dt.tz_convert('US/Central').dt.tz_localize(None)
    
    data.set_index('date', inplace=True)
    
    return data

# %%
ds_dict = {}

since = coinbase.parse8601('2023-01-01T00:00:00Z')
# symbols = ['BTC/USDT','ETH/USDT']
symbols = ['ETH/USDT']
# symbol='BTC/USDT'
timeframe = '1m'

for symbol in symbols:
    data = load_crypto_data(exchange=coinbase, since=since, symbol=symbol, timeframe=timeframe)
    ds_dict[symbol] = data

for i in list(ds_dict.keys()):
    ds_dict[i].to_csv(f'./data/{i[:3]}_historical_data_1m.csv')

# %%
btc_df = pd.read_csv(f'./data/BTC_historical_data_1m.csv').set_index('date')
eth_df = pd.read_csv(f'./data/ETH_historical_data_1m.csv').set_index('date')

data = pd.merge(btc_df, eth_df, on='date', suffixes=('_btc', '_eth'))
data.index = pd.to_datetime(data.index)
data = data.sort_index()

data.to_parquet('./data/btc_eth_historical_data_1m.parquet', engine='pyarrow', compression='gzip')
data.loc['2024-01-01':].to_parquet('./data/btc_eth_historical_data_2024_1m.parquet', engine='pyarrow',compression='gzip')

# %%
data = pd.read_parquet('./data/btc_eth_historical_data_1m.parquet')
data = data[~data.index.duplicated(keep='last')]
# data = data.groupby(data.index).mean()
# full_index = pd.date_range(start=data.index.min(), end=data.index.max(), freq='T')
# data = data.reindex(full_index).bfill()
data = data.dropna()

# %%
data.head()
# Out:
#                      open_btc  high_btc   low_btc  close_btc  volume_btc  \
# date
# 2021-12-31 18:00:00  46221.22  46257.95  46221.22   46226.81    0.092829
# 2021-12-31 18:01:00  46219.13  46311.86  46219.13   46306.76    0.104787
# 2021-12-31 18:02:00  46312.41  46375.03  46291.86   46351.02    1.666010
# 2021-12-31 18:04:00  46307.73  46307.73  46287.87   46295.59    0.120649
# 2021-12-31 18:05:00  46352.42  46447.55  46352.42   46447.55    0.042839
#
#                      open_eth  high_eth  low_eth  close_eth  volume_eth
# date
# 2021-12-31 18:00:00   3677.38   3683.82  3677.38    3682.34    5.045412
# 2021-12-31 18:01:00   3683.60   3691.11  3683.60    3690.89    3.178447
# 2021-12-31 18:02:00   3691.70   3694.29  3687.25    3694.29    5.722987
# 2021-12-31 18:04:00   3691.10   3691.52  3689.56    3690.41    4.011082
# 2021-12-31 18:05:00   3688.02   3699.28  3688.02    3699.28    0.495793

# %%
data.tail()
# Out:
#                      open_btc  high_btc   low_btc  close_btc  volume_btc  \
# date
# 2024-11-13 21:17:00  89627.60  89640.21  89549.81   89603.24    0.576530
# 2024-11-13 21:18:00  89537.05  89610.42  89535.00   89610.42    0.323637
# 2024-11-13 21:20:00  89742.35  89793.40  89742.35   89793.40    0.084266
# 2024-11-13 21:21:00  89806.80  89866.50  89806.80   89863.67    0.395072
# 2024-11-13 21:23:00  89916.93  90043.68  89916.93   90043.68    0.673799
#
#                      open_eth  high_eth  low_eth  close_eth  volume_eth
# date
# 2024-11-13 21:17:00   3182.31   3183.81  3180.71    3183.79    9.483672
# 2024-11-13 21:18:00   3184.40   3187.95  3182.98    3187.95    2.687577
# 2024-11-13 21:20:00   3188.40   3193.46  3188.40    3193.29   11.517766
# 2024-11-13 21:21:00   3195.52   3198.88  3194.79    3198.88    8.483672
# 2024-11-13 21:23:00   3196.71   3205.67  3196.71    3204.84   15.640058

# %%
plot_df = data[['close_btc']].copy()
plot_df.columns = ['BTC']
plot_df = plot_df.copy()

plt.figure(figsize=(12,6))
plt.plot(plot_df.index, plot_df['BTC'], label='BTC', color='blue')
# plt.plot(plot_df.index, plot_df['ETH'], label='ETH')
plt.title('BTC Close price')
plt.xlabel('date')
plt.ylabel('close price')
plt.legend()
plt.show()

# %%
plot_df = data[['close_eth']].copy()
plot_df.columns = ['ETH']
plot_df = plot_df.copy()

plt.figure(figsize=(12,6))
# plt.plot(plot_df.index, plot_df['BTC'], label='BTC')
plt.plot(plot_df.index, plot_df['ETH'], label='ETH', color='orange')
plt.title('ETH Close Price')
plt.xlabel('date')
plt.ylabel('close price')
plt.legend()
plt.show()

# %%
print(data.shape)
display(data.head())
display(data.tail())
# Out:
# (834957, 10)
#                      open_btc  high_btc   low_btc  close_btc  volume_btc  \
# date
# 2021-12-31 18:00:00  46221.22  46257.95  46221.22   46226.81    0.092829
# 2021-12-31 18:01:00  46219.13  46311.86  46219.13   46306.76    0.104787
# 2021-12-31 18:02:00  46312.41  46375.03  46291.86   46351.02    1.666010
# 2021-12-31 18:04:00  46307.73  46307.73  46287.87   46295.59    0.120649
# 2021-12-31 18:05:00  46352.42  46447.55  46352.42   46447.55    0.042839
#
#                      open_eth  high_eth  low_eth  close_eth  volume_eth
# date
# 2021-12-31 18:00:00   3677.38   3683.82  3677.38    3682.34    5.045412
# 2021-12-31 18:01:00   3683.60   3691.11  3683.60    3690.89    3.178447
# 2021-12-31 18:02:00   3691.70   3694.29  3687.25    3694.29    5.722987
# 2021-12-31 18:04:00   3691.10   3691.52  3689.56    3690.41    4.011082
# 2021-12-31 18:05:00   3688.02   3699.28  3688.02    3699.28    0.495793
#                      open_btc  high_btc   low_btc  close_btc  volume_btc  \
# date
# 2024-11-13 21:17:00  89627.60  89640.21  89549.81   89603.24    0.576530
# 2024-11-13 21:18:00  89537.05  89610.42  89535.00   89610.42    0.323637
# 2024-11-13 21:20:00  89742.35  89793.40  89742.35   89793.40    0.084266
# 2024-11-13 21:21:00  89806.80  89866.50  89806.80   89863.67    0.395072
# 2024-11-13 21:23:00  89916.93  90043.68  89916.93   90043.68    0.673799
#
#                      open_eth  high_eth  low_eth  close_eth  volume_eth
# date
# 2024-11-13 21:17:00   3182.31   3183.81  3180.71    3183.79    9.483672
# 2024-11-13 21:18:00   3184.40   3187.95  3182.98    3187.95    2.687577
# 2024-11-13 21:20:00   3188.40   3193.46  3188.40    3193.29   11.517766
# 2024-11-13 21:21:00   3195.52   3198.88  3194.79    3198.88    8.483672
# 2024-11-13 21:23:00   3196.71   3205.67  3196.71    3204.84   15.640058

# %% [markdown]
# ## Data Preprocessing & Strategy Implementation
# - Normalization
# - Log Returns
# - Stationarity testing
#
# - $ Z = (X-\mu)/\sigma $
#     - When z-score is negative (price ratio < mean) ETH is overvalued compared to BTC since price ratio (BTC/ETH) decreased compared to historical average
#         - Long BTC / Short ETH
#     - When z-score is positive ETH is undervalued compared to BTC
#         - Short BTC / Long ETH

# %%
data['btc_norm'] = (data['close_btc'] - data['close_btc'].mean()) / data['close_btc'].std()
data['eth_norm'] = (data['close_eth'] - data['close_eth'].mean()) / data['close_eth'].std()

correlation_matrix = data[['close_btc','close_eth']].copy().corr()
norm_correlation_matrix = data[['btc_norm','eth_norm']].copy().corr()
# sn.heatmap(correlation_matrix, annot=True)
sn.heatmap(norm_correlation_matrix, annot=True)

asset1 = 'btc_norm'
asset2 = 'eth_norm'

test_data = data.loc['2024-10-01':]

result = ts.coint(test_data[asset1], test_data[asset2])

# print(f"p-value for augmented Engle-Granger test: {result[1]}")

# print(f"Asset p-value for Augmented Dickey-Fuller test: {adfuller(test_data[asset2])[1]}")
# print(f"Spread p-value for Augmented Dickey-Fuller test: {adfuller(test_data[asset1] - test_data[asset2])[1]}")
print(f"Price ratio p-value for Augmented Dickey-Fuller test: {adfuller(test_data[asset1]/test_data[asset2])[1]:.2%}")
# Out:
# Price ratio p-value for Augmented Dickey-Fuller test: 3.58%

# %%
def pairs_trading_strategy(df, entry_threshold=2, exit_threshold=0.5, rolling_window=60, trading_cost=0.30):
    data = df.copy()
    data['btc_norm'] = (data['close_btc'] - data['close_btc'].mean()) / data['close_btc'].std()
    data['eth_norm'] = (data['close_eth'] - data['close_eth'].mean()) / data['close_eth'].std()
    data['price_ratio'] = data['btc_norm'] / data['eth_norm']

    data['z_score'] = (data['price_ratio'] - data['price_ratio'].rolling(window=rolling_window).mean()) / data['price_ratio'].rolling(window=rolling_window).std()
    
    data['signal'] = 0 
    data.loc[data['z_score'] > entry_threshold, 'signal'] = -1 # Short signal (sell BTC, buy ETH)
    data.loc[data['z_score'] < -entry_threshold, 'signal'] = 1 # Long signal (buy BTC, sell ETH)
    data.loc[data['z_score'].abs() < exit_threshold, 'signal'] = 0 # Exit signal
    data['signal'] = data['signal'].shift(1)

    data['position'] = data['signal'].diff().fillna(0).abs()
    data.loc[data.index[0],'position'] = np.abs(data.loc[data.index[0],'signal'])
    data.loc[data.index[-1],'position'] = np.abs(0 - data.loc[data.index[-1],'signal'])
    
    data['btc_log_return'] = np.log(data['close_btc']/data['close_btc'].shift(1))
    data['eth_log_return'] = np.log(data['close_eth']/data['close_eth'].shift(1))
    
    data['strategy_return'] = data['signal'].shift() * data['btc_log_return'] - data['signal'].shift() * data['eth_log_return']
    data['strategy_return_tc'] = data['strategy_return'] - data['strategy_return']*data['position']*(trading_cost/100)
    return data

# %%
import optuna
import numpy as np
import pandas as pd

# Assuming pairs_trading_strategy is already defined
def pairs_trading_strategy(df, entry_threshold=2, exit_threshold=0.5, rolling_window=60):
    data = df.copy()
    data['btc_norm'] = (data['close_btc'] - data['close_btc'].mean()) / data['close_btc'].std()
    data['eth_norm'] = (data['close_eth'] - data['close_eth'].mean()) / data['close_eth'].std()
    data['price_ratio'] = data['btc_norm'] / data['eth_norm']
    
    data['z_score'] = (data['price_ratio'] - data['price_ratio'].rolling(window=rolling_window).mean()) / data['price_ratio'].rolling(window=rolling_window).std()
    
    data['signal'] = 0 
    data.loc[data['z_score'] > entry_threshold, 'signal'] = -1 # Short signal (sell BTC, buy ETH)
    data.loc[data['z_score'] < -entry_threshold, 'signal'] = 1 # Long signal (buy BTC, sell ETH)
    data.loc[data['z_score'].abs() < exit_threshold, 'signal'] = 0 # Exit signal
    data['signal'] = data['signal'].shift(1)
    
    data['btc_log_return'] = np.log(data['close_btc'] / data['close_btc'].shift(1))
    data['eth_log_return'] = np.log(data['close_eth'] / data['close_eth'].shift(1))
    
    # Calculate strategy returns
    data['strategy_return'] = data['signal'].shift() * data['btc_log_return'] - data['signal'].shift() * data['eth_log_return']
    
    # Return cumulative return as the objective
    data['cumulative_return'] = data['strategy_return'].cumsum().apply(np.exp)-1
    final_result = data['cumulative_return'].iloc[-1]
    return final_result # Cumulative return at the end

# Objective function for Optuna optimization
def objective(trial):
    # Suggest values for the hyperparameters within the defined ranges
    entry_threshold = trial.suggest_float('entry_threshold', 1.0, 3.0)  # Range between 1 and 3
    exit_threshold = trial.suggest_float('exit_threshold', 0.2, 1)   # Range between 0.2 and 1
    rolling_window = trial.suggest_int('rolling_window', 10, 200)  # Range between 20 and 100
    
    # Example data (replace with your actual data)
    start_date = '2023-01-01'
    optuna_data = pd.DataFrame({
        'close_btc': data.loc[start_date:,'close_btc'],  # Replace with actual BTC closing prices
        'close_eth': data.loc[start_date:,'close_eth'],  # Replace with actual ETH closing prices
    })
    
    # Run the pairs trading strategy and get the cumulative return
    return pairs_trading_strategy(optuna_data, entry_threshold, exit_threshold, rolling_window)

# Create an Optuna study to optimize the objective function
study = optuna.create_study(direction='maximize')  # We want to maximize the cumulative return

# Optimize the study for 100 trials (you can change the number of trials based on your needs)
study.optimize(objective, n_trials=100)

# Output the best trial and parameters
print(f"Best trial number: {study.best_trial.number}")
print(f"Best parameters: {study.best_trial.params}")
print(f"Best cumulative return: {study.best_value}")
# Out:
# [I 2024-11-15 11:36:26,803] A new study created in memory with name: no-name-a308cae0-3c45-4b74-b999-3a6f22b4451e
# [I 2024-11-15 11:36:26,942] Trial 0 finished with value: -0.24410998866764932 and parameters: {'entry_threshold': 2.3240559949903465, 'exit_threshold': 0.844851682662636, 'rolling_window': 78}. Best is trial 0 with value: -0.24410998866764932.
# [I 2024-11-15 11:36:27,053] Trial 1 finished with value: -0.28948754283512346 and parameters: {'entry_threshold': 2.3882446259904917, 'exit_threshold': 0.9196358749476496, 'rolling_window': 31}. Best is trial 0 with value: -0.24410998866764932.
# [I 2024-11-15 11:36:27,169] Trial 2 finished with value: -0.39081739356846856 and parameters: {'entry_threshold': 1.4626103127772023, 'exit_threshold': 0.5036641940023319, 'rolling_window': 60}. Best is trial 0 with value: -0.24410998866764932.
# [I 2024-11-15 11:36:27,277] Trial 3 finished with value: -0.18119704298821937 and parameters: {'entry_threshold': 2.978908420738077, 'exit_threshold': 0.5272239645768286, 'rolling_window': 164}. Best is trial 3 with value: -0.18119704298821937.
# [I 2024-11-15 11:36:27,389] Trial 4 finished with value: -0.16786720769963148 and parameters: {'entry_threshold': 2.30068652413041, 'exit_threshold': 0.20022997029936818, 'rolling_window': 14}. Best is trial 4 with value: -0.16786720769963148.
# [I 2024-11-15 11:36:27,502] Trial 5 finished with value: -0.4341966738131938 and parameters: {'entry_threshold': 1.6415463189460384, 'exit_threshold': 0.5358787390598261, 'rolling_window': 49}. Best is trial 4 with value: -0.16786720769963148.
# [I 2024-11-15 11:36:27,615] Trial 6 finished with value: -0.12200743588612384 and parameters: {'entry_threshold': 2.139150897918478, 'exit_threshold': 0.5738665683921932, 'rolling_window': 152}. Best is trial 6 with value: -0.12200743588612384.
# [I 2024-11-15 11:36:27,724] Trial 7 finished with value: 0.0344563177186572 and parameters: {'entry_threshold': 1.2477356033967013, 'exit_threshold': 0.4356739722621864, 'rolling_window': 175}. Best is trial 7 with value: 0.0344563177186572.
# [I 2024-11-15 11:36:27,834] Trial 8 finished with value: -0.2854204997096488 and parameters: {'entry_threshold': 2.305396119905736, 'exit_threshold': 0.21695743779804044, 'rolling_window': 44}. Best is trial 7 with value: 0.0344563177186572.
# [I 2024-11-15 11:36:27,945] Trial 9 finished with value: -0.3200349617114515 and parameters: {'entry_threshold': 2.928943543290185, 'exit_threshold': 0.9247071907315991, 'rolling_window': 49}. Best is trial 7 with value: 0.0344563177186572.
# [I 2024-11-15 11:36:28,083] Trial 10 finished with value: -0.05756366217726472 and parameters: {'entry_threshold': 1.0393365141951345, 'exit_threshold': 0.36620632226276284, 'rolling_window': 200}. Best is trial 7 with value: 0.0344563177186572.
# [I 2024-11-15 11:36:28,214] Trial 11 finished with value: 0.01717388288392807 and parameters: {'entry_threshold': 1.024049040032211, 'exit_threshold': 0.34000517198423835, 'rolling_window': 188}. Best is trial 7 with value: 0.0344563177186572.
# [I 2024-11-15 11:36:28,347] Trial 12 finished with value: 0.05100727232329172 and parameters: {'entry_threshold': 1.055655841955828, 'exit_threshold': 0.38795884976452577, 'rolling_window': 133}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:28,482] Trial 13 finished with value: -0.1981947813469005 and parameters: {'entry_threshold': 1.4048994740052057, 'exit_threshold': 0.7201398214582815, 'rolling_window': 124}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:28,609] Trial 14 finished with value: -0.2750057202527735 and parameters: {'entry_threshold': 1.7646453082063807, 'exit_threshold': 0.3700382491339786, 'rolling_window': 118}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:28,738] Trial 15 finished with value: -0.008749802042003596 and parameters: {'entry_threshold': 1.3092338822569372, 'exit_threshold': 0.6935019035620125, 'rolling_window': 148}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:28,874] Trial 16 finished with value: -0.1990511000291445 and parameters: {'entry_threshold': 1.2012270618115142, 'exit_threshold': 0.40717692457123067, 'rolling_window': 91}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,010] Trial 17 finished with value: -0.1481970451612603 and parameters: {'entry_threshold': 1.86316804370682, 'exit_threshold': 0.44775434323189633, 'rolling_window': 175}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,141] Trial 18 finished with value: -0.1407621392282148 and parameters: {'entry_threshold': 1.5929389742830313, 'exit_threshold': 0.2828332424310551, 'rolling_window': 134}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,272] Trial 19 finished with value: -0.10098171471649531 and parameters: {'entry_threshold': 1.1442226520232226, 'exit_threshold': 0.6539766881316842, 'rolling_window': 101}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,425] Trial 20 finished with value: 0.0009634930411905884 and parameters: {'entry_threshold': 1.2911676045467186, 'exit_threshold': 0.46265204978054475, 'rolling_window': 172}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,559] Trial 21 finished with value: -0.02689976959134699 and parameters: {'entry_threshold': 1.006847719036619, 'exit_threshold': 0.29380450495871024, 'rolling_window': 197}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,690] Trial 22 finished with value: -0.0125372657188203 and parameters: {'entry_threshold': 1.0012448433934316, 'exit_threshold': 0.31458676457737106, 'rolling_window': 185}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,833] Trial 23 finished with value: -0.058583033128053796 and parameters: {'entry_threshold': 1.4999467576714998, 'exit_threshold': 0.41221121085824103, 'rolling_window': 147}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:29,966] Trial 24 finished with value: 0.038050579772700655 and parameters: {'entry_threshold': 1.1988780568778836, 'exit_threshold': 0.3177166720393351, 'rolling_window': 184}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,099] Trial 25 finished with value: -0.053774278526164454 and parameters: {'entry_threshold': 1.2364941346567824, 'exit_threshold': 0.2477202198064209, 'rolling_window': 161}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,235] Trial 26 finished with value: -0.2589487684181021 and parameters: {'entry_threshold': 1.8945060377129916, 'exit_threshold': 0.6299142225380906, 'rolling_window': 134}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,369] Trial 27 finished with value: -0.21021888230691554 and parameters: {'entry_threshold': 2.6976928901975095, 'exit_threshold': 0.3856803909358301, 'rolling_window': 180}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,507] Trial 28 finished with value: -0.1988236633140723 and parameters: {'entry_threshold': 1.362242147201005, 'exit_threshold': 0.4676985114051997, 'rolling_window': 113}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,645] Trial 29 finished with value: -0.27397524149130414 and parameters: {'entry_threshold': 1.581026227593953, 'exit_threshold': 0.7471911396131847, 'rolling_window': 80}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,784] Trial 30 finished with value: 0.038548034042545476 and parameters: {'entry_threshold': 1.149109997393637, 'exit_threshold': 0.5654722527103971, 'rolling_window': 159}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:30,916] Trial 31 finished with value: -0.005157840680407921 and parameters: {'entry_threshold': 1.1559501789462745, 'exit_threshold': 0.607722720537128, 'rolling_window': 162}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,051] Trial 32 finished with value: 0.03360131433746494 and parameters: {'entry_threshold': 1.1529516613882416, 'exit_threshold': 0.8060846196910416, 'rolling_window': 135}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,181] Trial 33 finished with value: -0.16145408757755275 and parameters: {'entry_threshold': 1.429675796979273, 'exit_threshold': 0.5490720532110165, 'rolling_window': 169}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,309] Trial 34 finished with value: -0.01389967888927035 and parameters: {'entry_threshold': 1.2968950966148716, 'exit_threshold': 0.5015171912075284, 'rolling_window': 151}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,444] Trial 35 finished with value: 0.003642581339807993 and parameters: {'entry_threshold': 1.717050796578362, 'exit_threshold': 0.4430052759381162, 'rolling_window': 140}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,575] Trial 36 finished with value: 0.03505255358133841 and parameters: {'entry_threshold': 1.1243268463062002, 'exit_threshold': 0.5008991347893328, 'rolling_window': 190}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,707] Trial 37 finished with value: -0.017172822265941967 and parameters: {'entry_threshold': 1.1167794007118599, 'exit_threshold': 0.5108428750688755, 'rolling_window': 195}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,834] Trial 38 finished with value: -0.1894344605952646 and parameters: {'entry_threshold': 1.4939687728558209, 'exit_threshold': 0.9915381567667371, 'rolling_window': 189}. Best is trial 12 with value: 0.05100727232329172.
# [I 2024-11-15 11:36:31,963] Trial 39 finished with value: 0.08184923167668412 and parameters: {'entry_threshold': 1.1004186106232132, 'exit_threshold': 0.2573449848335938, 'rolling_window': 160}. Best is trial 39 with value: 0.08184923167668412.
# [I 2024-11-15 11:36:32,091] Trial 40 finished with value: -0.22472549404006115 and parameters: {'entry_threshold': 2.1082669950369866, 'exit_threshold': 0.24157496012257856, 'rolling_window': 161}. Best is trial 39 with value: 0.08184923167668412.
# [I 2024-11-15 11:36:32,219] Trial 41 finished with value: 0.06956041568856008 and parameters: {'entry_threshold': 1.095454211833561, 'exit_threshold': 0.27598071613394726, 'rolling_window': 160}. Best is trial 39 with value: 0.08184923167668412.
# [I 2024-11-15 11:36:32,348] Trial 42 finished with value: 0.07045677402139572 and parameters: {'entry_threshold': 1.087199110969368, 'exit_threshold': 0.27171678836754426, 'rolling_window': 156}. Best is trial 39 with value: 0.08184923167668412.
# [I 2024-11-15 11:36:32,476] Trial 43 finished with value: 0.041411333886628654 and parameters: {'entry_threshold': 1.0797136929968374, 'exit_threshold': 0.26520792391402837, 'rolling_window': 155}. Best is trial 39 with value: 0.08184923167668412.
# [I 2024-11-15 11:36:32,601] Trial 44 finished with value: -0.16060388944602577 and parameters: {'entry_threshold': 2.5570285850027243, 'exit_threshold': 0.20494794279672135, 'rolling_window': 128}. Best is trial 39 with value: 0.08184923167668412.
# [I 2024-11-15 11:36:32,728] Trial 45 finished with value: 0.17123636122675578 and parameters: {'entry_threshold': 1.073647930031205, 'exit_threshold': 0.26384202641228083, 'rolling_window': 142}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:32,857] Trial 46 finished with value: -0.27309988129061435 and parameters: {'entry_threshold': 1.3444454568327167, 'exit_threshold': 0.34994866615099024, 'rolling_window': 107}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:32,991] Trial 47 finished with value: -0.017253640929461356 and parameters: {'entry_threshold': 1.2463643279777274, 'exit_threshold': 0.24613972524331793, 'rolling_window': 143}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,118] Trial 48 finished with value: 0.04993041420956135 and parameters: {'entry_threshold': 1.0598712969518616, 'exit_threshold': 0.3088702183688014, 'rolling_window': 126}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,244] Trial 49 finished with value: -0.12094997315234346 and parameters: {'entry_threshold': 1.4162079966144543, 'exit_threshold': 0.21231625443906052, 'rolling_window': 142}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,381] Trial 50 finished with value: -0.01604152649843993 and parameters: {'entry_threshold': 1.250074366263969, 'exit_threshold': 0.26743286071005257, 'rolling_window': 168}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,514] Trial 51 finished with value: 0.0875112666201332 and parameters: {'entry_threshold': 1.071879838377915, 'exit_threshold': 0.3185838538325024, 'rolling_window': 125}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,647] Trial 52 finished with value: 0.09579033017899263 and parameters: {'entry_threshold': 1.0824797929755796, 'exit_threshold': 0.33386511386103257, 'rolling_window': 115}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,811] Trial 53 finished with value: -0.023469813951823237 and parameters: {'entry_threshold': 1.0925932544908967, 'exit_threshold': 0.3372709609968082, 'rolling_window': 120}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:33,955] Trial 54 finished with value: 0.16310651592649505 and parameters: {'entry_threshold': 1.0144702056544193, 'exit_threshold': 0.278948775729356, 'rolling_window': 97}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,099] Trial 55 finished with value: 0.022008026654428914 and parameters: {'entry_threshold': 1.0171090331421064, 'exit_threshold': 0.3386887111831102, 'rolling_window': 86}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,249] Trial 56 finished with value: -0.42165394440608484 and parameters: {'entry_threshold': 1.193860383918059, 'exit_threshold': 0.2321739658493556, 'rolling_window': 64}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,399] Trial 57 finished with value: -0.24650230876467205 and parameters: {'entry_threshold': 1.3683004233037621, 'exit_threshold': 0.2970754890348507, 'rolling_window': 98}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,544] Trial 58 finished with value: -0.47182922119933335 and parameters: {'entry_threshold': 1.2897236790696338, 'exit_threshold': 0.3632876094117157, 'rolling_window': 12}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,677] Trial 59 finished with value: -0.08139735740165621 and parameters: {'entry_threshold': 1.0020716823255693, 'exit_threshold': 0.3850448092441127, 'rolling_window': 107}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,803] Trial 60 finished with value: -0.03504330698315972 and parameters: {'entry_threshold': 1.5438363543945641, 'exit_threshold': 0.3224957508129102, 'rolling_window': 114}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:34,940] Trial 61 finished with value: -0.15540633142446236 and parameters: {'entry_threshold': 1.117097948136948, 'exit_threshold': 0.2862728714461447, 'rolling_window': 94}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,086] Trial 62 finished with value: 0.06181888595563634 and parameters: {'entry_threshold': 1.0731970257938004, 'exit_threshold': 0.2520326341137247, 'rolling_window': 153}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,227] Trial 63 finished with value: 0.06877486699967461 and parameters: {'entry_threshold': 1.2015243868971075, 'exit_threshold': 0.2886030779993946, 'rolling_window': 120}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,364] Trial 64 finished with value: -0.21781468353698652 and parameters: {'entry_threshold': 1.0775278164818765, 'exit_threshold': 0.22357378293543895, 'rolling_window': 29}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,507] Trial 65 finished with value: 0.018163411564832144 and parameters: {'entry_threshold': 1.2028884293406543, 'exit_threshold': 0.270083880252788, 'rolling_window': 178}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,643] Trial 66 finished with value: -0.1583434644890711 and parameters: {'entry_threshold': 2.437825442103514, 'exit_threshold': 0.41255314567603607, 'rolling_window': 71}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,781] Trial 67 finished with value: -0.08630892200251361 and parameters: {'entry_threshold': 1.2826497508500008, 'exit_threshold': 0.2033499240196174, 'rolling_window': 129}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:35,916] Trial 68 finished with value: 0.12159521434362786 and parameters: {'entry_threshold': 1.0038904399535515, 'exit_threshold': 0.3263535701634199, 'rolling_window': 147}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,050] Trial 69 finished with value: 0.017626123719341136 and parameters: {'entry_threshold': 1.005923486913109, 'exit_threshold': 0.32234213128140166, 'rolling_window': 137}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,179] Trial 70 finished with value: -0.13580647482879415 and parameters: {'entry_threshold': 2.8876724401300295, 'exit_threshold': 0.3553419463937729, 'rolling_window': 146}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,315] Trial 71 finished with value: 0.017042074169963062 and parameters: {'entry_threshold': 1.1514472942874256, 'exit_threshold': 0.27408368192527494, 'rolling_window': 156}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,445] Trial 72 finished with value: 0.09555076095816384 and parameters: {'entry_threshold': 1.0725363068954488, 'exit_threshold': 0.31553194189597256, 'rolling_window': 111}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,575] Trial 73 finished with value: 0.0026769625181453094 and parameters: {'entry_threshold': 1.043115313907765, 'exit_threshold': 0.39703796374138545, 'rolling_window': 112}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,705] Trial 74 finished with value: -0.20918564109271476 and parameters: {'entry_threshold': 1.1784069934030346, 'exit_threshold': 0.29878708570972534, 'rolling_window': 102}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,838] Trial 75 finished with value: -0.24587690314827482 and parameters: {'entry_threshold': 1.2423006832421322, 'exit_threshold': 0.4231858403108338, 'rolling_window': 92}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:36,971] Trial 76 finished with value: -0.16193374846181052 and parameters: {'entry_threshold': 1.3361720931177636, 'exit_threshold': 0.33409925104645766, 'rolling_window': 130}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,104] Trial 77 finished with value: 0.05641936640269751 and parameters: {'entry_threshold': 1.0601729554905353, 'exit_threshold': 0.37514637773542503, 'rolling_window': 123}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,241] Trial 78 finished with value: 0.09462748238683116 and parameters: {'entry_threshold': 1.1394013592164476, 'exit_threshold': 0.2515973296176813, 'rolling_window': 166}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,376] Trial 79 finished with value: 0.07233005472982579 and parameters: {'entry_threshold': 1.1375803234879038, 'exit_threshold': 0.22874623000965855, 'rolling_window': 167}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,505] Trial 80 finished with value: 0.06418534373121698 and parameters: {'entry_threshold': 1.001311423871947, 'exit_threshold': 0.30691962523133326, 'rolling_window': 85}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,634] Trial 81 finished with value: 0.019349935651786332 and parameters: {'entry_threshold': 1.1430328283433706, 'exit_threshold': 0.2292805559149298, 'rolling_window': 170}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,763] Trial 82 finished with value: 0.046581900797709075 and parameters: {'entry_threshold': 1.2170904156235967, 'exit_threshold': 0.250657397838466, 'rolling_window': 150}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:37,898] Trial 83 finished with value: 0.05932757823856627 and parameters: {'entry_threshold': 1.1258004196566205, 'exit_threshold': 0.2268011436795207, 'rolling_window': 165}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:38,028] Trial 84 finished with value: -0.23097034424848473 and parameters: {'entry_threshold': 2.2062000224753304, 'exit_threshold': 0.25225988686224327, 'rolling_window': 110}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:38,153] Trial 85 finished with value: 0.14938598679051518 and parameters: {'entry_threshold': 1.0522295627372187, 'exit_threshold': 0.3171069032655257, 'rolling_window': 138}. Best is trial 45 with value: 0.17123636122675578.
# [I 2024-11-15 11:36:38,281] Trial 86 finished with value: 0.1767353044018214 and parameters: {'entry_threshold': 1.056811720353562, 'exit_threshold': 0.313164213864446, 'rolling_window': 137}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:38,432] Trial 87 finished with value: -0.0980955704536699 and parameters: {'entry_threshold': 1.9641243831030208, 'exit_threshold': 0.368774567050231, 'rolling_window': 117}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:38,562] Trial 88 finished with value: 0.011873949701827202 and parameters: {'entry_threshold': 1.0513120100756537, 'exit_threshold': 0.32147331307673266, 'rolling_window': 131}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:38,689] Trial 89 finished with value: 0.010238776155602425 and parameters: {'entry_threshold': 1.1774414049875952, 'exit_threshold': 0.3388476739369127, 'rolling_window': 137}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:38,818] Trial 90 finished with value: 0.04081075951754354 and parameters: {'entry_threshold': 1.055714600271393, 'exit_threshold': 0.3013264850869388, 'rolling_window': 124}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:38,947] Trial 91 finished with value: 0.11246356407248048 and parameters: {'entry_threshold': 1.1026161662675653, 'exit_threshold': 0.2922799096913738, 'rolling_window': 145}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,072] Trial 92 finished with value: -0.007080528884171766 and parameters: {'entry_threshold': 1.2541551626885836, 'exit_threshold': 0.3572823788148897, 'rolling_window': 141}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,192] Trial 93 finished with value: 0.04444105706650081 and parameters: {'entry_threshold': 1.1104177653411564, 'exit_threshold': 0.2842212386824886, 'rolling_window': 146}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,313] Trial 94 finished with value: 0.050909928845579655 and parameters: {'entry_threshold': 1.0311556679937626, 'exit_threshold': 0.3160548590678017, 'rolling_window': 134}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,436] Trial 95 finished with value: 0.01427408073544334 and parameters: {'entry_threshold': 1.0420799637065543, 'exit_threshold': 0.35026717511946553, 'rolling_window': 102}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,562] Trial 96 finished with value: -0.012281784284993269 and parameters: {'entry_threshold': 1.179985945148469, 'exit_threshold': 0.3959527830220933, 'rolling_window': 139}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,685] Trial 97 finished with value: 0.09335646268803677 and parameters: {'entry_threshold': 1.1005682386220326, 'exit_threshold': 0.8324499190894427, 'rolling_window': 117}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,811] Trial 98 finished with value: 0.07113669844265713 and parameters: {'entry_threshold': 1.1066407398116926, 'exit_threshold': 0.8470118020031686, 'rolling_window': 117}. Best is trial 86 with value: 0.1767353044018214.
# [I 2024-11-15 11:36:39,935] Trial 99 finished with value: -0.2715849552673901 and parameters: {'entry_threshold': 1.2638989021610934, 'exit_threshold': 0.6814709838465176, 'rolling_window': 99}. Best is trial 86 with value: 0.1767353044018214.
# Best trial number: 86
# Best parameters: {'entry_threshold': 1.056811720353562, 'exit_threshold': 0.313164213864446, 'rolling_window': 137}
# Best cumulative return: 0.1767353044018214

# %%
# Best parameters: {'entry_threshold': 1.0412046076288992, 'exit_threshold': 0.27043047652464947, 'rolling_window': 187}
# Best cumulative return: 0.7575809000595151

# Best parameters: {'entry_threshold': 1.1168824356922697, 'exit_threshold': 0.3174327081743927, 'rolling_window': 148}
# Best cumulative return: 0.17917225477292642

for date in [
    data.loc['2022-01-01':'2022-03-31'], 
    data.loc['2022-04-01':'2022-06-30'], 
    data.loc['2022-07-01':'2022-09-30'], 
    data.loc['2022-10-01':'2022-12-31'],
    data.loc['2023-01-01':'2023-03-31'],
    data.loc['2023-04-01':'2023-06-30'],
    data.loc['2023-07-01':'2023-09-30'],
    data.loc['2023-10-01':'2023-12-31'],
    data.loc['2024-01-01':'2024-03-31'],
    data.loc['2024-04-01':'2024-06-30'],
    data.loc['2024-07-01':'2024-09-30'],
    data.loc['2022-01-01':'2024-09-30']
]:
    back_test = pairs_trading_strategy(date, 
                                    entry_threshold=1.0, 
                                    exit_threshold=0.6, 
                                    rolling_window=150).copy()

    back_test['strategy_cumulative_return'] = back_test['strategy_return'].cumsum().apply(np.exp)-1
    back_test['strategy_cumulative_return_tc'] = back_test['strategy_return_tc'].cumsum().apply(np.exp)-1
    back_test['btc_cumulative_return'] = back_test['btc_log_return'].cumsum().apply(np.exp)-1
    back_test['eth_cumulative_return'] = back_test['eth_log_return'].cumsum().apply(np.exp)-1

    print(f"Strategy cumulative return: {back_test['strategy_cumulative_return_tc'].iloc[-1]}")

    plot_df = back_test[['btc_cumulative_return','eth_cumulative_return','strategy_cumulative_return_tc']].copy()
    plot_df.columns = ['BTC','ETH','Strategy']
    plot_df = plot_df.copy()
    strat_return = back_test['strategy_cumulative_return_tc'].iloc[-1]
    btc_return = back_test['btc_cumulative_return'].iloc[-1]
    eth_return = back_test['eth_cumulative_return'].iloc[-1]

    plt.figure(figsize=(14,7))
    plt.plot(plot_df.index, plot_df['BTC'], label='BTC', color='blue')
    plt.plot(plot_df.index, plot_df['ETH'], label='ETH', color='purple')
    plt.plot(plot_df.index, plot_df['Strategy'], label='Strategy', color='red')
    plt.title(f"Cumulative Return: Benchmarks: BTC {btc_return:.2%} & ETH {eth_return: .2%} vs Strategy {strat_return:.2%}")
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return')
    plt.legend()
    plt.show()
# Out:
# Strategy cumulative return: -0.046025292960925834
# Strategy cumulative return: 0.18938475139984412
# Strategy cumulative return: -0.3162679498936223
# Strategy cumulative return: -0.16531070277906412
# Strategy cumulative return: -0.18987217791567057
# Strategy cumulative return: -0.1483309708446725
# Strategy cumulative return: 0.10188995826597957
# Strategy cumulative return: 0.11287249003973487
# Strategy cumulative return: 0.01892006350994424
# Strategy cumulative return: -0.07127395080646448
# Strategy cumulative return: 0.08164326765931995
# Strategy cumulative return: 0.8419664224019712

# %%
back_test.loc[back_test]

# %%
back_test.signal.value_counts().to_frame('Number of Transactions')
# Out:
#         Number of Transactions
# signal
#  0.0                    393811
# -1.0                    204301
#  1.0                    203370

# %%
benchmark=back_test['btc_log_return'].to_frame('BTC Risk Metrics').dropna()
strategy=back_test['strategy_return_tc'].to_frame('Strategy Risk Metrics').dropna()

strategy_risk_metrics = ats.calc_risk_metrics(
                    strategy,
                    benchmark,
                    as_df=True,
                    adj=60*24*365)

btc_risk_metrics = ats.calc_risk_metrics(
                    benchmark,
                    benchmark,
                    as_df=True,
                    adj=60*24*365)

performance_metrics = pd.concat([strategy_risk_metrics, btc_risk_metrics], axis=0).fillna(0)



performance_metrics[['VaR (0.05)', 'CVaR (0.05)', 'Min', 'Max',
       'Tracking Error', 'Information Ratio', 'Max Drawdown']]
# Out:
#                        VaR (0.05)  CVaR (0.05)       Min       Max  \
# Strategy Risk Metrics   -0.000922    -0.001602 -0.059253  0.043257
# BTC Risk Metrics        -0.001487    -0.002393 -0.044797  0.045741
#
#                        Tracking Error  Information Ratio  Max Drawdown
# Strategy Risk Metrics        0.889937           0.227282     -0.406525
# BTC Risk Metrics             0.000000           0.000000     -0.739485

# %%
performance_metrics.columns
# Out:
# Index(['Mean', 'Volatility', 'Sharpe Ratio', 'Sortino Ratio', 'Skewness',
#        'Excess Kurtosis', 'VaR (0.05)', 'CVaR (0.05)', 'Min', 'Max',
#        'Tracking Error', 'Information Ratio', 'Max Drawdown'],
#       dtype='object')

# %%
te = pd.concat([benchmark, strategy], axis=1).dropna()
te = te.iloc[:,1] - te.iloc[:,0]
te.values.reshape(-1,1).mean()*(60*24*365)
# Out:
# 0.20226664762931448

# %%
(te.values.reshape(-1,1).mean()*(60*24*365)).std()
# Out:
# 0.0

# %%
import sys

def forget_module(module_name):
    if module_name in sys.modules:
        del sys.modules[module_name]
        print(f"Module '{module_name}' has been forgotten (removed from sys.modules).")
        return True
    else:
        print(f"Module '{module_name}' is not currently loaded.")
        return False
    
forget_module('algo_tools') 


from algo_tools import algo_tools as ats
# Out:
# Module 'algo_tools' has been forgotten (removed from sys.modules).
